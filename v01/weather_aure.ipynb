# %% [markdown]
# # 生成天气图表

# %%
# 依赖包
from src import meteo_config_aure as config
from src import weather_charts_builder

# 基础数据
countries = config.countries # 涉及的国家、地区
daily_indicators = config.daily_indicators  #需要查询的指标

# 存档的历史数据
au_path = ['dataset/AU_2020-2024.csv',
           'dataset/AU_202501-202509.csv']
eu_path = ['dataset/EU_2020-2024.csv',
           'dataset/EU_202501-202509.csv']
ru_path = ['dataset/RU_2020-2024.csv',
           'dataset/RU_202501-202509.csv']
ua_path = ['dataset/UA_2020-2024.csv',
           'dataset/UA_202501-202509.csv']
countries[0]['csv_path'] = au_path
countries[1]['csv_path'] = eu_path
countries[2]['csv_path'] = ru_path
countries[3]['csv_path'] = ua_path

# 绘制保存图表
params = {
    'countries' : countries,
    'api_start_date' : '2025-10-01',
    'api_end_date'   : '2025-10-09',
    'forecast_start_date' : '2025-10-10',
    'forecast_end_date' : '2025-10-25',
    'daily_indicators' : daily_indicators,
    'config' : config
}
weather_charts_builder.with_forecast(**params)
# Out:
# .. Loading: Queensland
# .. Loading: New South Wales
# .. Loading: Victoria
# .. Loading: South Australia
# .. Loading: Western Australia
# Finished: Australia
# .. Loading: Spain
# .. Loading: France
# .. Loading: Germany
# .. Loading: Poland
# .. Loading: Romania
# Finished: Europe Union
# .. Loading: Rostov
# .. Loading: Belgorod
# .. Loading: Saratov
# .. Loading: Altai
# .. Loading: Stavropol
# Finished: Russia
# .. Loading: Chernihiv
# .. Loading: Poltava
# .. Loading: Vinnytsia
# .. Loading: Dnipropetrovsk
# .. Loading: Kharkiv
# .. Loading: Odesa
# Finished: Ukraine

# %% [markdown]
# # 合并图片

# %%
from src import charts
from src import meteo_config_aure as config

for country in config.countries:
    file_lists = []
    for city in country['city_list']:
        for style in config.styles:
            file_lists.append(f'diagram/{country['code']}/{country['code']}{city['code']}_{style['path']}.jpg')
    charts.merge2grid(file_lists, len(country['city_list']), len(config.styles), f'diagram/grid/{country['code']}.jpg')

# %% [markdown]
# # 保存历史数据

# %%
# 保存历史数据
from src import meteo_config_aure as config
from src import weather_history_saver

params = {
    'countries': config.countries,
    'start_date': '2025-09-01',
    'end_date': '2025-09-30',
    'daily_indicators': config.daily_indicators,
    'tail_of_file': '202509'
}

weather_history_saver.save(**params)
# Out:
# .. Loading: Queensland
# .. Loading: New South Wales
# .. Loading: Victoria
# .. Loading: South Australia
# .. Loading: Western Australia
# Finished: Australia
# .. Loading: Spain
# .. Loading: France
# .. Loading: Germany
# .. Loading: Poland
# .. Loading: Romania
# Finished: Europe Union
# .. Loading: Rostov
# .. Loading: Belgorod
# .. Loading: Saratov
# .. Loading: Altai
# .. Loading: Stavropol
# Finished: Russia
# .. Loading: Chernihiv
# .. Loading: Poltava
# .. Loading: Vinnytsia
# .. Loading: Dnipropetrovsk
# .. Loading: Kharkiv
# .. Loading: Odesa
# Finished: Ukraine

# %% [markdown]
# # 合并历史数据文件

# %%
# 合并历史数据文件
import pandas as pd
from src import meteo_config_aure as config

tail_of_input_file = ['202501-202508', '202509']
tail_of_output_file = '202501-202509'

for country in config.countries:
    out_df = pd.DataFrame()
    for t in tail_of_input_file:
        in_df = pd.read_csv(f'dataset/{country['code']}_{t}.csv', sep=',')
        out_df = pd.concat([out_df, in_df])
    out_df.to_csv(f'dataset/{country["code"]}_{tail_of_output_file}.csv', index=False)
