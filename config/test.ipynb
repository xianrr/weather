# %%
# from __future__ import annotations
# from dataclasses import dataclass, field
# from typing import List, Optional, Tuple
# import pandas as pd
#
# @dataclass
# class City:
#     """ 城市（或州、省）下的经纬度样本集合
#     - code: 城市/州代码
#     - name: 名称
#     - latitude/longitude: 该城市内一个或多个样本点的纬度、经度组成的
#     - title_tag: （可选）标题附加标签，部分区域需要
#     """
#     code: str
#     name: str
#     latitude: List[float]
#     longitude: List[float]
#
#
# City('FJ','Fujian', [1,2,3],[2,3,4])

# %%
import meteo_config
a = meteo_config.City('C','na', [1],[2])
a
# Out:
# meteo_config.City
